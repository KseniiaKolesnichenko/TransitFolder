# %% [markdown]
# # Библиотеки токенизации текста
#
# Курс "Обработка естественного языка".
#
# Токенизация текста на русском языке с использованием библиотек:
# - [Natural Language Toolkit (NLTK)](https://www.nltk.org/).
# - [TensorFlow Text](https://www.tensorflow.org/text/guide/tokenizers).
# - [spaCy](https://spacy.io).

# %%
# !pip install tensorflow-text spacy==3.3
# Out:
# Requirement already satisfied: tensorflow-text in /usr/local/lib/python3.7/dist-packages (2.9.0)
# Requirement already satisfied: spacy==3.3 in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (1.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (2.4.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (1.21.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (0.6.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (0.4.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (0.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (57.4.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (3.10.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (8.0.15)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (0.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (4.64.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (1.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.3) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy==3.3) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy==3.3) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy==3.3) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.3) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.3) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy==3.3) (7.1.2)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (0.12.0)
# Requirement already satisfied: tensorflow<2.10,>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (14.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.46.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.12)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (0.25.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (3.17.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.10,>=2.9.0->tensorflow-text) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.10,>=2.9.0->tensorflow-text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.10,>=2.9.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (3.3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (4.11.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<2.10,>=2.9.0->tensorflow-text) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy==3.3) (2.0.1)

# %%
import requests
import nltk
import spacy
import tensorflow as tf
import tensorflow_text as tf_text
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# Текст для токенизации

# %%
text = """
Илья Сегалович родился в семье советского геофизика В.И.Сегаловича. Детство провёл в 
Казахстане. В Республиканской физико-математической школе познакомился с будущим сооснователем 
«Яндекса» Аркадием Воложем. В 1981 году поступил в Московский геологоразведочный институт 
им.Орджоникидзе.

С самого основания «Яндекса» и до своей смерти Илья Сегалович занимал позицию директора по 
технологиям, был ключевым архитектором поисковых технологий и инициатором многих продуктов 
компании, например, Яндекс.Директа, голосового помощника «Алиса» и беспилотного автомобиля.
"""

# %% [markdown]
# ## Разделение на слова по пробелам

# %%
text.split()
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«Яндекса»',
#  'Аркадием',
#  'Воложем.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе.',
#  'С',
#  'самого',
#  'основания',
#  '«Яндекса»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям,',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании,',
#  'например,',
#  'Яндекс.Директа,',
#  'голосового',
#  'помощника',
#  '«Алиса»',
#  'и',
#  'беспилотного',
#  'автомобиля.']

# %% [markdown]
# ## Разделение на символы

# %%
list(text)
# Out:
# ['\n',
#  'И',
#  'л',
#  'ь',
#  'я',
#  ' ',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  ' ',
#  'р',
#  'о',
#  'д',
#  'и',
#  'л',
#  'с',
#  'я',
#  ' ',
#  'в',
#  ' ',
#  'с',
#  'е',
#  'м',
#  'ь',
#  'е',
#  ' ',
#  'с',
#  'о',
#  'в',
#  'е',
#  'т',
#  'с',
#  'к',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'г',
#  'е',
#  'о',
#  'ф',
#  'и',
#  'з',
#  'и',
#  'к',
#  'а',
#  ' ',
#  'В',
#  '.',
#  'И',
#  '.',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  'а',
#  '.',
#  ' ',
#  'Д',
#  'е',
#  'т',
#  'с',
#  'т',
#  'в',
#  'о',
#  ' ',
#  'п',
#  'р',
#  'о',
#  'в',
#  'ё',
#  'л',
#  ' ',
#  'в',
#  ' ',
#  '\n',
#  'К',
#  'а',
#  'з',
#  'а',
#  'х',
#  'с',
#  'т',
#  'а',
#  'н',
#  'е',
#  '.',
#  ' ',
#  'В',
#  ' ',
#  'Р',
#  'е',
#  'с',
#  'п',
#  'у',
#  'б',
#  'л',
#  'и',
#  'к',
#  'а',
#  'н',
#  'с',
#  'к',
#  'о',
#  'й',
#  ' ',
#  'ф',
#  'и',
#  'з',
#  'и',
#  'к',
#  'о',
#  '-',
#  'м',
#  'а',
#  'т',
#  'е',
#  'м',
#  'а',
#  'т',
#  'и',
#  'ч',
#  'е',
#  'с',
#  'к',
#  'о',
#  'й',
#  ' ',
#  'ш',
#  'к',
#  'о',
#  'л',
#  'е',
#  ' ',
#  'п',
#  'о',
#  'з',
#  'н',
#  'а',
#  'к',
#  'о',
#  'м',
#  'и',
#  'л',
#  'с',
#  'я',
#  ' ',
#  'с',
#  ' ',
#  'б',
#  'у',
#  'д',
#  'у',
#  'щ',
#  'и',
#  'м',
#  ' ',
#  'с',
#  'о',
#  'о',
#  'с',
#  'н',
#  'о',
#  'в',
#  'а',
#  'т',
#  'е',
#  'л',
#  'е',
#  'м',
#  ' ',
#  '\n',
#  '«',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'А',
#  'р',
#  'к',
#  'а',
#  'д',
#  'и',
#  'е',
#  'м',
#  ' ',
#  'В',
#  'о',
#  'л',
#  'о',
#  'ж',
#  'е',
#  'м',
#  '.',
#  ' ',
#  'В',
#  ' ',
#  '1',
#  '9',
#  '8',
#  '1',
#  ' ',
#  'г',
#  'о',
#  'д',
#  'у',
#  ' ',
#  'п',
#  'о',
#  'с',
#  'т',
#  'у',
#  'п',
#  'и',
#  'л',
#  ' ',
#  'в',
#  ' ',
#  'М',
#  'о',
#  'с',
#  'к',
#  'о',
#  'в',
#  'с',
#  'к',
#  'и',
#  'й',
#  ' ',
#  'г',
#  'е',
#  'о',
#  'л',
#  'о',
#  'г',
#  'о',
#  'р',
#  'а',
#  'з',
#  'в',
#  'е',
#  'д',
#  'о',
#  'ч',
#  'н',
#  'ы',
#  'й',
#  ' ',
#  'и',
#  'н',
#  'с',
#  'т',
#  'и',
#  'т',
#  'у',
#  'т',
#  ' ',
#  '\n',
#  'и',
#  'м',
#  '.',
#  'О',
#  'р',
#  'д',
#  'ж',
#  'о',
#  'н',
#  'и',
#  'к',
#  'и',
#  'д',
#  'з',
#  'е',
#  '.',
#  '\n',
#  '\n',
#  'С',
#  ' ',
#  'с',
#  'а',
#  'м',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'о',
#  'с',
#  'н',
#  'о',
#  'в',
#  'а',
#  'н',
#  'и',
#  'я',
#  ' ',
#  '«',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'и',
#  ' ',
#  'д',
#  'о',
#  ' ',
#  'с',
#  'в',
#  'о',
#  'е',
#  'й',
#  ' ',
#  'с',
#  'м',
#  'е',
#  'р',
#  'т',
#  'и',
#  ' ',
#  'И',
#  'л',
#  'ь',
#  'я',
#  ' ',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  ' ',
#  'з',
#  'а',
#  'н',
#  'и',
#  'м',
#  'а',
#  'л',
#  ' ',
#  'п',
#  'о',
#  'з',
#  'и',
#  'ц',
#  'и',
#  'ю',
#  ' ',
#  'д',
#  'и',
#  'р',
#  'е',
#  'к',
#  'т',
#  'о',
#  'р',
#  'а',
#  ' ',
#  'п',
#  'о',
#  ' ',
#  '\n',
#  'т',
#  'е',
#  'х',
#  'н',
#  'о',
#  'л',
#  'о',
#  'г',
#  'и',
#  'я',
#  'м',
#  ',',
#  ' ',
#  'б',
#  'ы',
#  'л',
#  ' ',
#  'к',
#  'л',
#  'ю',
#  'ч',
#  'е',
#  'в',
#  'ы',
#  'м',
#  ' ',
#  'а',
#  'р',
#  'х',
#  'и',
#  'т',
#  'е',
#  'к',
#  'т',
#  'о',
#  'р',
#  'о',
#  'м',
#  ' ',
#  'п',
#  'о',
#  'и',
#  'с',
#  'к',
#  'о',
#  'в',
#  'ы',
#  'х',
#  ' ',
#  'т',
#  'е',
#  'х',
#  'н',
#  'о',
#  'л',
#  'о',
#  'г',
#  'и',
#  'й',
#  ' ',
#  'и',
#  ' ',
#  'и',
#  'н',
#  'и',
#  'ц',
#  'и',
#  'а',
#  'т',
#  'о',
#  'р',
#  'о',
#  'м',
#  ' ',
#  'м',
#  'н',
#  'о',
#  'г',
#  'и',
#  'х',
#  ' ',
#  'п',
#  'р',
#  'о',
#  'д',
#  'у',
#  'к',
#  'т',
#  'о',
#  'в',
#  ' ',
#  '\n',
#  'к',
#  'о',
#  'м',
#  'п',
#  'а',
#  'н',
#  'и',
#  'и',
#  ',',
#  ' ',
#  'н',
#  'а',
#  'п',
#  'р',
#  'и',
#  'м',
#  'е',
#  'р',
#  ',',
#  ' ',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  '.',
#  'Д',
#  'и',
#  'р',
#  'е',
#  'к',
#  'т',
#  'а',
#  ',',
#  ' ',
#  'г',
#  'о',
#  'л',
#  'о',
#  'с',
#  'о',
#  'в',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'п',
#  'о',
#  'м',
#  'о',
#  'щ',
#  'н',
#  'и',
#  'к',
#  'а',
#  ' ',
#  '«',
#  'А',
#  'л',
#  'и',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'и',
#  ' ',
#  'б',
#  'е',
#  'с',
#  'п',
#  'и',
#  'л',
#  'о',
#  'т',
#  'н',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'а',
#  'в',
#  'т',
#  'о',
#  'м',
#  'о',
#  'б',
#  'и',
#  'л',
#  'я',
#  '.',
#  '\n']

# %% [markdown]
# ## Библиотека [NLTK](https://www.nltk.org/)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Токенизация по предложениям

# %%
sentences = sent_tokenize(text)

# %%
print(sentences)
# Out:
# ['\nИлья Сегалович родился в семье советского геофизика В.И.Сегаловича.', 'Детство провёл в \nКазахстане.', 'В Республиканской физико-математической школе познакомился с будущим сооснователем \n«Яндекса» Аркадием Воложем.', 'В 1981 году поступил в Московский геологоразведочный институт \nим.Орджоникидзе.', 'С самого основания «Яндекса» и до своей смерти Илья Сегалович занимал позицию директора по \nтехнологиям, был ключевым архитектором поисковых технологий и инициатором многих продуктов \nкомпании, например, Яндекс.Директа, голосового помощника «Алиса» и беспилотного автомобиля.']

# %% [markdown]
# Токенизация по словам

# %%
words = word_tokenize(text)

# %%
words
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича',
#  '.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане',
#  '.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«',
#  'Яндекса',
#  '»',
#  'Аркадием',
#  'Воложем',
#  '.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе',
#  '.',
#  'С',
#  'самого',
#  'основания',
#  '«',
#  'Яндекса',
#  '»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям',
#  ',',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании',
#  ',',
#  'например',
#  ',',
#  'Яндекс.Директа',
#  ',',
#  'голосового',
#  'помощника',
#  '«',
#  'Алиса',
#  '»',
#  'и',
#  'беспилотного',
#  'автомобиля',
#  '.']

# %% [markdown]
# ## Библиотека [TensorFlow Text](https://www.tensorflow.org/text/guide/tokenizers)

# %% [markdown]
# Разделение на слова

# %%
tokenizer = tf_text.WhitespaceTokenizer()
tokens = tokenizer.tokenize([text])
tokens.to_list()
# Out:
# [[b'\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f',
#   b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87',
#   b'\xd1\x80\xd0\xbe\xd0\xb4\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f',
#   b'\xd0\xb2',
#   b'\xd1\x81\xd0\xb5\xd0\xbc\xd1\x8c\xd0\xb5',
#   b'\xd1\x81\xd0\xbe\xd0\xb2\xd0\xb5\xd1\x82\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xb3\xd0\xb5\xd0\xbe\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb0',
#   b'\xd0\x92.\xd0\x98.\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87\xd0\xb0.',
#   b'\xd0\x94\xd0\xb5\xd1\x82\xd1\x81\xd1\x82\xd0\xb2\xd0\xbe',
#   b'\xd0\xbf\xd1\x80\xd0\xbe\xd0\xb2\xd1\x91\xd0\xbb',
#   b'\xd0\xb2',
#   b'\xd0\x9a\xd0\xb0\xd0\xb7\xd0\xb0\xd1\x85\xd1\x81\xd1\x82\xd0\xb0\xd0\xbd\xd0\xb5.',
#   b'\xd0\x92',
#   b'\xd0\xa0\xd0\xb5\xd1\x81\xd0\xbf\xd1\x83\xd0\xb1\xd0\xbb\xd0\xb8\xd0\xba\xd0\xb0\xd0\xbd\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9',
#   b'\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xbe-\xd0\xbc\xd0\xb0\xd1\x82\xd0\xb5\xd0\xbc\xd0\xb0\xd1\x82\xd0\xb8\xd1\x87\xd0\xb5\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9',
#   b'\xd1\x88\xd0\xba\xd0\xbe\xd0\xbb\xd0\xb5',
#   b'\xd0\xbf\xd0\xbe\xd0\xb7\xd0\xbd\xd0\xb0\xd0\xba\xd0\xbe\xd0\xbc\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f',
#   b'\xd1\x81',
#   b'\xd0\xb1\xd1\x83\xd0\xb4\xd1\x83\xd1\x89\xd0\xb8\xd0\xbc',
#   b'\xd1\x81\xd0\xbe\xd0\xbe\xd1\x81\xd0\xbd\xd0\xbe\xd0\xb2\xd0\xb0\xd1\x82\xd0\xb5\xd0\xbb\xd0\xb5\xd0\xbc',
#   b'\xc2\xab\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81\xd0\xb0\xc2\xbb',
#   b'\xd0\x90\xd1\x80\xd0\xba\xd0\xb0\xd0\xb4\xd0\xb8\xd0\xb5\xd0\xbc',
#   b'\xd0\x92\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb6\xd0\xb5\xd0\xbc.',
#   b'\xd0\x92',
#   b'1981',
#   b'\xd0\xb3\xd0\xbe\xd0\xb4\xd1\x83',
#   b'\xd0\xbf\xd0\xbe\xd1\x81\xd1\x82\xd1\x83\xd0\xbf\xd0\xb8\xd0\xbb',
#   b'\xd0\xb2',
#   b'\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xbe\xd0\xb2\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9',
#   b'\xd0\xb3\xd0\xb5\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xbe\xd1\x80\xd0\xb0\xd0\xb7\xd0\xb2\xd0\xb5\xd0\xb4\xd0\xbe\xd1\x87\xd0\xbd\xd1\x8b\xd0\xb9',
#   b'\xd0\xb8\xd0\xbd\xd1\x81\xd1\x82\xd0\xb8\xd1\x82\xd1\x83\xd1\x82',
#   b'\xd0\xb8\xd0\xbc.\xd0\x9e\xd1\x80\xd0\xb4\xd0\xb6\xd0\xbe\xd0\xbd\xd0\xb8\xd0\xba\xd0\xb8\xd0\xb4\xd0\xb7\xd0\xb5.',
#   b'\xd0\xa1',
#   b'\xd1\x81\xd0\xb0\xd0\xbc\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xbe\xd1\x81\xd0\xbd\xd0\xbe\xd0\xb2\xd0\xb0\xd0\xbd\xd0\xb8\xd1\x8f',
#   b'\xc2\xab\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81\xd0\xb0\xc2\xbb',
#   b'\xd0\xb8',
#   b'\xd0\xb4\xd0\xbe',
#   b'\xd1\x81\xd0\xb2\xd0\xbe\xd0\xb5\xd0\xb9',
#   b'\xd1\x81\xd0\xbc\xd0\xb5\xd1\x80\xd1\x82\xd0\xb8',
#   b'\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f',
#   b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87',
#   b'\xd0\xb7\xd0\xb0\xd0\xbd\xd0\xb8\xd0\xbc\xd0\xb0\xd0\xbb',
#   b'\xd0\xbf\xd0\xbe\xd0\xb7\xd0\xb8\xd1\x86\xd0\xb8\xd1\x8e',
#   b'\xd0\xb4\xd0\xb8\xd1\x80\xd0\xb5\xd0\xba\xd1\x82\xd0\xbe\xd1\x80\xd0\xb0',
#   b'\xd0\xbf\xd0\xbe',
#   b'\xd1\x82\xd0\xb5\xd1\x85\xd0\xbd\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xb8\xd1\x8f\xd0\xbc,',
#   b'\xd0\xb1\xd1\x8b\xd0\xbb',
#   b'\xd0\xba\xd0\xbb\xd1\x8e\xd1\x87\xd0\xb5\xd0\xb2\xd1\x8b\xd0\xbc',
#   b'\xd0\xb0\xd1\x80\xd1\x85\xd0\xb8\xd1\x82\xd0\xb5\xd0\xba\xd1\x82\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbc',
#   b'\xd0\xbf\xd0\xbe\xd0\xb8\xd1\x81\xd0\xba\xd0\xbe\xd0\xb2\xd1\x8b\xd1\x85',
#   b'\xd1\x82\xd0\xb5\xd1\x85\xd0\xbd\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xb8\xd0\xb9',
#   b'\xd0\xb8',
#   b'\xd0\xb8\xd0\xbd\xd0\xb8\xd1\x86\xd0\xb8\xd0\xb0\xd1\x82\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbc',
#   b'\xd0\xbc\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xb8\xd1\x85',
#   b'\xd0\xbf\xd1\x80\xd0\xbe\xd0\xb4\xd1\x83\xd0\xba\xd1\x82\xd0\xbe\xd0\xb2',
#   b'\xd0\xba\xd0\xbe\xd0\xbc\xd0\xbf\xd0\xb0\xd0\xbd\xd0\xb8\xd0\xb8,',
#   b'\xd0\xbd\xd0\xb0\xd0\xbf\xd1\x80\xd0\xb8\xd0\xbc\xd0\xb5\xd1\x80,',
#   b'\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81.\xd0\x94\xd0\xb8\xd1\x80\xd0\xb5\xd0\xba\xd1\x82\xd0\xb0,',
#   b'\xd0\xb3\xd0\xbe\xd0\xbb\xd0\xbe\xd1\x81\xd0\xbe\xd0\xb2\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xbf\xd0\xbe\xd0\xbc\xd0\xbe\xd1\x89\xd0\xbd\xd0\xb8\xd0\xba\xd0\xb0',
#   b'\xc2\xab\xd0\x90\xd0\xbb\xd0\xb8\xd1\x81\xd0\xb0\xc2\xbb',
#   b'\xd0\xb8',
#   b'\xd0\xb1\xd0\xb5\xd1\x81\xd0\xbf\xd0\xb8\xd0\xbb\xd0\xbe\xd1\x82\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xb0\xd0\xb2\xd1\x82\xd0\xbe\xd0\xbc\xd0\xbe\xd0\xb1\xd0\xb8\xd0\xbb\xd1\x8f.']]

# %%
[token.decode('utf-8') for token in tokens.to_list()[0]]
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«Яндекса»',
#  'Аркадием',
#  'Воложем.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе.',
#  'С',
#  'самого',
#  'основания',
#  '«Яндекса»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям,',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании,',
#  'например,',
#  'Яндекс.Директа,',
#  'голосового',
#  'помощника',
#  '«Алиса»',
#  'и',
#  'беспилотного',
#  'автомобиля.']

# %% [markdown]
# Разделение на части слов – токенизатор Sentencepiece

# %%
url = "https://github.com/tensorflow/text/blob/master/tensorflow_text/python/ops/test_data/test_oss_model.model?raw=true"
sp_model = requests.get(url).content

# %%
tokenizer = tf_text.SentencepieceTokenizer(sp_model, out_type=tf.string)
tokens = tokenizer.tokenize([text])
print(tokens.to_list())
# Out:
# [[b'\xe2\x96\x81', b'\n\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f', b'\xe2\x96\x81', b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87', b'\xe2\x96\x81', b'\xd1\x80\xd0\xbe\xd0\xb4\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f', b'\xe2\x96\x81', b'\xd0\xb2', b'\xe2\x96\x81', b'\xd1\x81\xd0\xb5\xd0\xbc\xd1\x8c\xd0\xb5', b'\xe2\x96\x81', b'\xd1\x81\xd0\xbe\xd0\xb2\xd0\xb5\xd1\x82\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe', b'\xe2\x96\x81', b'\xd0\xb3\xd0\xb5\xd0\xbe\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb0', b'\xe2\x96\x81', b'\xd0\x92', b'.', b'\xd0\x98', b'.', b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87\xd0\xb0', b'.', b'\xe2\x96\x81', b'\xd0\x94\xd0\xb5\xd1\x82\xd1\x81\xd1\x82\xd0\xb2\xd0\xbe', b'\xe2\x96\x81', b'\xd0\xbf\xd1\x80\xd0\xbe\xd0\xb2\xd1\x91\xd0\xbb', b'\xe2\x96\x81', b'\xd0\xb2', b'\xe2\x96\x81', b'\n\xd0\x9a\xd0\xb0\xd0\xb7\xd0\xb0\xd1\x85\xd1\x81\xd1\x82\xd0\xb0\xd0\xbd\xd0\xb5', b'.', b'\xe2\x96\x81', b'\xd0\x92', b'\xe2\x96\x81', b'\xd0\xa0\xd0\xb5\xd1\x81\xd0\xbf\xd1\x83\xd0\xb1\xd0\xbb\xd0\xb8\xd0\xba\xd0\xb0\xd0\xbd\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9', b'\xe2\x96\x81', b'\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xbe', b'-', b'\xd0\xbc\xd0\xb0\xd1\x82\xd0\xb5\xd0\xbc\xd0\xb0\xd1\x82\xd0\xb8\xd1\x87\xd0\xb5\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9', b'\xe2\x96\x81', b'\xd1\x88\xd0\xba\xd0\xbe\xd0\xbb\xd0\xb5', b'\xe2\x96\x81', b'\xd0\xbf\xd0\xbe\xd0\xb7\xd0\xbd\xd0\xb0\xd0\xba\xd0\xbe\xd0\xbc\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f', b'\xe2\x96\x81', b'\xd1\x81', b'\xe2\x96\x81', b'\xd0\xb1\xd1\x83\xd0\xb4\xd1\x83\xd1\x89\xd0\xb8\xd0\xbc', b'\xe2\x96\x81', b'\xd1\x81\xd0\xbe\xd0\xbe\xd1\x81\xd0\xbd\xd0\xbe\xd0\xb2\xd0\xb0\xd1\x82\xd0\xb5\xd0\xbb\xd0\xb5\xd0\xbc', b'\xe2\x96\x81', b'\n\xc2\xab\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81\xd0\xb0\xc2\xbb', b'\xe2\x96\x81', b'\xd0\x90\xd1\x80\xd0\xba\xd0\xb0\xd0\xb4\xd0\xb8\xd0\xb5\xd0\xbc', b'\xe2\x96\x81', b'\xd0\x92\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb6\xd0\xb5\xd0\xbc', b'.', b'\xe2\x96\x81', b'\xd0\x92', b'\xe2\x96\x81', b'1', b'9', b'8', b'1', b'\xe2\x96\x81', b'\xd0\xb3\xd0\xbe\xd0\xb4\xd1\x83', b'\xe2\x96\x81', b'\xd0\xbf\xd0\xbe\xd1\x81\xd1\x82\xd1\x83\xd0\xbf\xd0\xb8\xd0\xbb', b'\xe2\x96\x81', b'\xd0\xb2', b'\xe2\x96\x81', b'\xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xbe\xd0\xb2\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9', b'\xe2\x96\x81', b'\xd0\xb3\xd0\xb5\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xbe\xd1\x80\xd0\xb0\xd0\xb7\xd0\xb2\xd0\xb5\xd0\xb4\xd0\xbe\xd1\x87\xd0\xbd\xd1\x8b\xd0\xb9', b'\xe2\x96\x81', b'\xd0\xb8\xd0\xbd\xd1\x81\xd1\x82\xd0\xb8\xd1\x82\xd1\x83\xd1\x82', b'\xe2\x96\x81', b'\n\xd0\xb8\xd0\xbc', b'.', b'\xd0\x9e\xd1\x80\xd0\xb4\xd0\xb6\xd0\xbe\xd0\xbd\xd0\xb8\xd0\xba\xd0\xb8\xd0\xb4\xd0\xb7\xd0\xb5', b'.', b'\n\n\xd0\xa1', b'\xe2\x96\x81', b'\xd1\x81\xd0\xb0\xd0\xbc\xd0\xbe\xd0\xb3\xd0\xbe', b'\xe2\x96\x81', b'\xd0\xbe\xd1\x81\xd0\xbd\xd0\xbe\xd0\xb2\xd0\xb0\xd0\xbd\xd0\xb8\xd1\x8f', b'\xe2\x96\x81', b'\xc2\xab\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81\xd0\xb0\xc2\xbb', b'\xe2\x96\x81', b'\xd0\xb8', b'\xe2\x96\x81', b'\xd0\xb4\xd0\xbe', b'\xe2\x96\x81', b'\xd1\x81\xd0\xb2\xd0\xbe\xd0\xb5\xd0\xb9', b'\xe2\x96\x81', b'\xd1\x81\xd0\xbc\xd0\xb5\xd1\x80\xd1\x82\xd0\xb8', b'\xe2\x96\x81', b'\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f', b'\xe2\x96\x81', b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87', b'\xe2\x96\x81', b'\xd0\xb7\xd0\xb0\xd0\xbd\xd0\xb8\xd0\xbc\xd0\xb0\xd0\xbb', b'\xe2\x96\x81', b'\xd0\xbf\xd0\xbe\xd0\xb7\xd0\xb8\xd1\x86\xd0\xb8\xd1\x8e', b'\xe2\x96\x81', b'\xd0\xb4\xd0\xb8\xd1\x80\xd0\xb5\xd0\xba\xd1\x82\xd0\xbe\xd1\x80\xd0\xb0', b'\xe2\x96\x81', b'\xd0\xbf\xd0\xbe', b'\xe2\x96\x81', b'\n\xd1\x82\xd0\xb5\xd1\x85\xd0\xbd\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xb8\xd1\x8f\xd0\xbc', b',', b'\xe2\x96\x81', b'\xd0\xb1\xd1\x8b\xd0\xbb', b'\xe2\x96\x81', b'\xd0\xba\xd0\xbb\xd1\x8e\xd1\x87\xd0\xb5\xd0\xb2\xd1\x8b\xd0\xbc', b'\xe2\x96\x81', b'\xd0\xb0\xd1\x80\xd1\x85\xd0\xb8\xd1\x82\xd0\xb5\xd0\xba\xd1\x82\xd0\xbe\xd ...

# %%
[token.decode('utf-8') for token in tokens.to_list()[0]]
# Out:
# ['▁',
#  '\nИлья',
#  '▁',
#  'Сегалович',
#  '▁',
#  'родился',
#  '▁',
#  'в',
#  '▁',
#  'семье',
#  '▁',
#  'советского',
#  '▁',
#  'геофизика',
#  '▁',
#  'В',
#  '.',
#  'И',
#  '.',
#  'Сегаловича',
#  '.',
#  '▁',
#  'Детство',
#  '▁',
#  'провёл',
#  '▁',
#  'в',
#  '▁',
#  '\nКазахстане',
#  '.',
#  '▁',
#  'В',
#  '▁',
#  'Республиканской',
#  '▁',
#  'физико',
#  '-',
#  'математической',
#  '▁',
#  'школе',
#  '▁',
#  'познакомился',
#  '▁',
#  'с',
#  '▁',
#  'будущим',
#  '▁',
#  'сооснователем',
#  '▁',
#  '\n«Яндекса»',
#  '▁',
#  'Аркадием',
#  '▁',
#  'Воложем',
#  '.',
#  '▁',
#  'В',
#  '▁',
#  '1',
#  '9',
#  '8',
#  '1',
#  '▁',
#  'году',
#  '▁',
#  'поступил',
#  '▁',
#  'в',
#  '▁',
#  'Московский',
#  '▁',
#  'геологоразведочный',
#  '▁',
#  'институт',
#  '▁',
#  '\nим',
#  '.',
#  'Орджоникидзе',
#  '.',
#  '\n\nС',
#  '▁',
#  'самого',
#  '▁',
#  'основания',
#  '▁',
#  '«Яндекса»',
#  '▁',
#  'и',
#  '▁',
#  'до',
#  '▁',
#  'своей',
#  '▁',
#  'смерти',
#  '▁',
#  'Илья',
#  '▁',
#  'Сегалович',
#  '▁',
#  'занимал',
#  '▁',
#  'позицию',
#  '▁',
#  'директора',
#  '▁',
#  'по',
#  '▁',
#  '\nтехнологиям',
#  ',',
#  '▁',
#  'был',
#  '▁',
#  'ключевым',
#  '▁',
#  'архитектором',
#  '▁',
#  'поисковых',
#  '▁',
#  'технологий',
#  '▁',
#  'и',
#  '▁',
#  'инициатором',
#  '▁',
#  'многих',
#  '▁',
#  'продуктов',
#  '▁',
#  '\nкомпании',
#  ',',
#  '▁',
#  'например',
#  ',',
#  '▁',
#  'Яндекс',
#  '.',
#  'Директа',
#  ',',
#  '▁',
#  'голосового',
#  '▁',
#  'помощника',
#  '▁',
#  '«Алиса»',
#  '▁',
#  'и',
#  '▁',
#  'беспилотного',
#  '▁',
#  'автомобиля',
#  '.',
#  '\n']

# %% [markdown]
# ## Библиотека [spaCy](spacy.io)

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.3.0/ru_core_news_sm-3.3.0-py3-none-any.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 3.8 MB/s
# Requirement already satisfied: pymorphy2>=0.9 in /usr/local/lib/python3.7/dist-packages (from ru-core-news-sm==3.3.0) (0.9.1)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from ru-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (2.4.417127.4579844)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.64.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (57.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.21.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.9.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.0.15)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.24.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
doc = nlp(text)

# %%
for tocken in doc:
    print(tocken)
# Out:
# Илья
# Сегалович
# родился
# в
# семье
# советского
# геофизика
# В.И.Сегаловича
# .
# Детство
# провёл
# в
#
#
# Казахстане
# .
# В
# Республиканской
# физико
# -
# математической
# школе
# познакомился
# с
# будущим
# сооснователем
#
#
# «
# Яндекса
# »
# Аркадием
# Воложем
# .
# В
# 1981
# году
# поступил
# в
# Московский
# геологоразведочный
# институт
#
#
# им.
# Орджоникидзе
# .
#
#
#
# С
# самого
# основания
# «
# Яндекса
# »
# и
# до
# своей
# смерти
# Илья
# Сегалович
# занимал
# позицию
# директора
# по
#
#
# технологиям
# ,
# был
# ключевым
# архитектором
# поисковых
# технологий
# и
# инициатором
# многих
# продуктов
#
#
# компании
# ,
# например
# ,
# Яндекс
# .
# Директа
# ,
# голосового
# помощника
# «
# Алиса
# »
# и
# беспилотного
# автомобиля
# .

# %% [markdown]
# ## Полезные ссылки
#
# 1. [Библиотека Natural Language Toolkit (NLTK)](https://www.nltk.org/).
# 2. [Библиотека TensorFlow Text](https://www.tensorflow.org/text/guide/tokenizers).
# 3. [Библиотека spaCy](https://spacy.io).
# 4. [Токенизаторы в HuggingFace](https://huggingface.co/docs/transformers/tokenizer_summary).
#
# ## Благодарности
#
# Проект реализуется победителем Конкурса на предоставление грантов преподавателям магистратуры 2020/2021 благотворительной программы «Стипендиальная программа Владимира Потанина» Благотворительного фонда Владимира Потанина.
